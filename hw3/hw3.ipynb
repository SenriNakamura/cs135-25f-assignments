# %% [markdown]
# # HW3 : Logistic Regression and Neural Networks
#
# ### Instructions
#
# The authoritative HW3 instructions are on the course website:
#
# http://www.cs.tufts.edu/cs/135/2025f/hw3.html
#
# Please report any questions to Piazza.
#
# ### Outline of this Notebook

# %%
import os
import numpy as np
import pandas as pd
import time
import warnings

# %%
# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.0, style='whitegrid')

# %% [markdown]
# Allow autoreload of student-edited code to be reflected in this notebook

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import LRGradientDescent 

insert_final_col_of_all_ones = LRGradientDescent.insert_final_col_of_all_ones
LogisticRegressionGradientDescent = LRGradientDescent.LogisticRegressionGradientDescent

# %% [markdown]
# # Create toy dataset with F=1 input dimension
#
# Each input $x_n$ is one position on number line
#
# Each label $y_n$ is binary, either 0 or 1

# %%
# Toy problem 
# Logistic regression should be able to perfectly predict all 10 examples
N = 10
xoffset = 1.23
x_NF = xoffset + np.hstack([
    np.linspace(-2, -1, 5), np.linspace(1, 2, 5)])[:,np.newaxis]
y_N = np.hstack([np.zeros(5), np.ones(5)])

# %%
plt.plot(x_NF[:,0], y_N, 'ks');
plt.xlabel('x');
plt.ylabel('y');

# %% [markdown]
# ## Setup

# %%
fixedb = -1.0 # Fix bias coef at -1 for now, we'll learn it later in 1B

xone_NG = insert_final_col_of_all_ones(x_NF)

# %% [markdown]
# ## Debugging Figure: Show phat as function of x for different w
#
# You don't need this for your report, but this is for your *understanding* to make sure your predict_proba is correct
#
# No need to edit here. Read thru to understand this code and what it's doing.
# Then use it to help debug your `predict_proba` implementation

# %%
w_candidates_A = [-1., 1, 3, 7]

A = len(w_candidates_A)
fig, axgrid = plt.subplots(nrows=1, ncols=A, figsize=(4*A+1,3), sharex=True, sharey=True)

L = 101
xdense_L = np.linspace(-2, 4, L)
xdense_L1 = xdense_L[:,np.newaxis]

tmplr = LogisticRegressionGradientDescent(C=1000.0)

for aa in range(len(w_candidates_A)):
    curw = w_candidates_A[aa]
    
    # Hard-code the values of wtil_G so they reflect current w value
    tmplr.wtil_G = np.asarray([curw, fixedb]);
    
    # Evaluate phat with current wtil_G, across L different dense x values
    phat_L = tmplr.predict_proba(xdense_L1)[:,1]

    # Show predicted phat probability alongside true labels
    axgrid[aa].plot(xdense_L, phat_L, 'm-');
    axgrid[aa].plot(x_NF[:,0], y_N, 'k.', markersize=8);
    
    # Make pretty title to help with debugging
    curJ = tmplr.calc_loss(tmplr.wtil_G, xone_NG, y_N)
    panel = axgrid[aa]
    panel.set_title('  w  =% .1f  b=%.1f\nJ(w) = %.3f ' % (curw, fixedb, curJ),
                         x=0.0,
                         font='monospace', fontsize=14,
                         horizontalalignment='left')
    panel.set_xticks([-2, 0, 2, 4]);
    panel.set_xlabel(r'$x_n$')
    if aa == 0:
        panel.set_ylabel(r'$p(y_n=1 | x_n)$');

# %% [markdown]
# ## Step 1A: Evaluate loss and grad across dense grid of w values
#
# This prepares for Fig 1a

# %%
fixedb = -1.0 # Fix bias coef

# %%
xone_NG = insert_final_col_of_all_ones(x_NF)
G = xone_NG.shape[1]

# %%
mylr = LogisticRegressionGradientDescent(C=10.0)

# %%
## Perform numerical search over a fine grid of w values
H = 201 # num grid points
w_grid_H = np.linspace(-2, 11, H)
loss_grid_H = np.zeros_like(w_grid_H)
grad_grid_H = np.zeros_like(w_grid_H)

for hh in range(H):
    wtil_G = np.asarray([w_grid_H[hh], fixedb])
    loss = mylr.calc_loss(wtil_G, xone_NG, y_N)
    grad_G = mylr.calc_grad(wtil_G, xone_NG, y_N)
    loss_grid_H[hh] = loss
    grad_grid_H[hh] = grad_G[0]

# %% [markdown]
# ## Figure 1a: Loss and Grad vs w
#
# If your calc_loss and calc_grad implementations are correct, you shouldn't need to edit anything in this block
#
# This block helps visualize loss J and its grad as a function of w

# %%
fig, axgrid = plt.subplots(nrows=1, ncols=2, figsize=(7,3), sharex=True, sharey=False)

loss_panel = axgrid[0]
loss_panel.plot(w_grid_H, loss_grid_H, 'b-');
loss_panel.set_ylim([0.0, 5.0]);
loss_panel.set_xticks([-2, 0, 2, 4, 6, 8, 10]);
loss_panel.set_xlabel('w')
loss_panel.set_ylabel('loss J')

grad_panel = axgrid[1]
grad_panel.plot(w_grid_H, grad_grid_H, 'b-');
grad_panel.set_ylim([-2, 1]);
grad_panel.set_yticks([-2, -1, 0, 1]);
grad_panel.set_xlabel('w')
grad_panel.set_ylabel('grad of J wrt w')

plt.suptitle("Fig 1a: loss and grad when C = %.3g" % mylr.C, fontsize=12);

plt.tight_layout();

# %% [markdown]
# ## Caption of Fig 1a: Part 1

# %% [markdown]
# Write in report. See instructions.

# %% [markdown]
# ## Caption of Fig 1a: Part 2

# %% [markdown]
# TODO find the values in w_grid_H that correspond to lowest loss value in loss_grid_H
#
# Make sure the answer here gets moved to your report

# %%
# Find index of minimum loss
min_idx = np.argmin(loss_grid_H)
w_min = w_grid_H[min_idx]

# Report as a tight 0.1-wide interval around the min
print("Lowest value is between %.3f and %.3f" % (w_min, w_min + 0.1))
# Out:
# Lowest value is between 2.290 and 2.390

# %% [markdown]
# ## Step 1B

# %% [markdown]
# Using this toy data, `init_w_recipe='zeros'` and call `fit` with an appropriate step size to run gradient descent. Be sure to verify convergence. If it doesn't converge, adjust your step size accordingly.

# %%
mylr_fromzeros = LogisticRegressionGradientDescent(
    C=50.0,
    step_size=4.5,       
    num_iterations=599,
    init_recipe='zeros',
    verbose=True         # show progress every ~20 iters
)

mylr_fromzeros.fit(x_NF, y_N)
print(mylr_fromzeros.solver_status)
# Out:
# Initializing G=2 parameters in wtil_G via recipe: zeros
# Running GD for up to 599 iters with step_size 4.5
# iter   0/599  loss   1.000000  avg_abs_grad   0.541011  w[0]   0.000 b   0.000
# iter   1/599  loss   0.367880  avg_abs_grad   0.119465  w[0]   4.869 b   0.000
# iter   2/599  loss   0.191857  avg_abs_grad   0.075171  w[0]   4.792 b  -0.998
# iter   3/599  loss   0.126264  avg_abs_grad   0.052688  w[0]   4.705 b  -1.587
# iter   4/599  loss   0.094845  avg_abs_grad   0.040204  w[0]   4.627 b  -1.983
# iter   5/599  loss   0.076935  avg_abs_grad   0.032504  w[0]   4.557 b  -2.276
# iter   6/599  loss   0.065472  avg_abs_grad   0.027335  w[0]   4.494 b  -2.505
# iter   7/599  loss   0.057529  avg_abs_grad   0.023635  w[0]   4.436 b  -2.693
# iter   8/599  loss   0.051704  avg_abs_grad   0.020847  w[0]   4.382 b  -2.852
# iter   9/599  loss   0.047251  avg_abs_grad   0.018662  w[0]   4.331 b  -2.988
# iter  10/599  loss   0.043737  avg_abs_grad   0.016889  w[0]   4.283 b  -3.108
# iter  11/599  loss   0.040898  avg_abs_grad   0.015409  w[0]   4.237 b  -3.215
# iter  12/599  loss   0.038561  avg_abs_grad   0.014143  w[0]   4.194 b  -3.311
# iter  13/599  loss   0.036612  avg_abs_grad   0.013035  w[0]   4.154 b  -3.397
# iter  14/599  loss   0.034968  avg_abs_grad   0.012049  w[0]   4.115 b  -3.476
# iter  15/599  loss   0.033572  avg_abs_grad   0.011155  w[0]   4.079 b  -3.548
# iter  16/599  loss   0.032380  avg_abs_grad   0.010335  w[0]   4.045 b  -3.615
# iter  17/599  loss   0.031360  avg_abs_grad   0.009574  w[0]   4.014 b  -3.676
# iter  18/599  loss   0.030485  avg_abs_grad   0.008862  w[0]   3.984 b  -3.733
# iter  19/599  loss   0.029734  avg_abs_grad   0.008191  w[0]   3.957 b  -3.786
# iter  20/599  loss   0.029090  avg_abs_grad   0.007558  w[0]   3.932 b  -3.835
# iter  21/599  loss   0.028538  avg_abs_grad   0.006959  w[0]   3.910 b  -3.880
# iter  40/599  loss   0.025278  avg_abs_grad   0.001978  w[0]   3.804 b  -4.364
# iter  41/599  loss   0.025229  avg_abs_grad   0.001946  w[0]   3.807 b  -4.378
# iter  60/599  loss   0.024668  avg_abs_grad   0.001339  w[0]   3.885 b  -4.582
# iter  61/599  loss   0.024650  avg_abs_grad   0.001311  w[0]   3.889 b  -4.590
# iter  80/599  loss   0.024417  avg_abs_grad   0.000900  w[0]   3.950 b  -4.717
# iter  81/599  loss   0.024409  avg_abs_grad   0.000884  w[0]   3.953 b  -4.723
# iter 100/599  loss   0.024300  avg_abs_grad   0.000625  w[0]   3.995 b  -4.810
# iter 101/599  loss   0.024296  avg_abs_grad   0.000614  w[0]   3.996 b  -4.813
# iter 120/599  loss   0.024242  avg_abs_grad   0.000444  w[0]   4.026 b  -4.875
# iter 121/599  loss   0.024240  avg_abs_grad   0.000437  w[0]   4.027 b  -4.877
# iter 140/599  loss   0.024212  avg_abs_grad   0.000321  w[0]   4.048 b  -4.921
# iter 141/599  loss   0.024211  avg_abs_grad   0.000316  w[0]   4.048 b  -4.923
# iter 160/599  loss   0.024197  avg_abs_grad   0.000235  w[0]   4.063 b  -4.956
# iter 161/599  loss   0.024196  avg_abs_grad   0.000231  w[0]   4.064 b  -4.957
# iter 180/599  loss   0.024188  avg_abs_grad   0.000173  w[0]   4.075 b  -4.981
# iter 181/599  loss   0.024188  avg_abs_grad   0.000170  w[0]   4.076 b  -4.982
# iter 200/599  loss   0.024184  avg_abs_grad   0.000128  w[0]   4.084 b  -4.999
# iter 201/599  loss   0.024183  avg_abs_grad   0.000126  w[0]   4.084 b  -5.000
# iter 220/599  loss   0.024181  avg_abs_grad   0.000095  w[0]   4.090 b  -5.013
# iter 221/599  loss   0.024181  avg_abs_grad   0.000094  w[0]   4.090 b  -5.013
# iter 240/599  loss   0.024180  avg_abs_grad   0.000071  w[0]   4.095 b  -5.023
# iter 241/599  loss   0.024180  avg_abs_grad   0.000070  w[0]   4.095 b  -5.024
# iter 260/599  loss   0.024179  avg_abs_grad   0.000053  w[0]   4.098 b  -5.031
# iter 261/599  loss   0.024179  avg_abs_grad   0.000052  w[0]   4.098 b  -5.031
# iter 280/599  loss   0.024178  avg_abs_grad   0.000040  w[0]   4.101 b  -5.037
# iter 281/599  loss   0.024178  avg_abs_grad   0.000039  w[0]   4.101 b  -5.037
# iter 300/599  loss   0.024178  avg_abs_grad   0.000030  w[0]   4.103 b  -5.041
# iter 301/599  loss   0.024178  avg_abs_grad   0.000029  w[0]   4.103 b  -5.041
# iter 320/599  loss   0.024178  avg_abs_grad   0.000022  w[0]   4.104 b  -5.044
# iter 321/599  loss   0.024178  avg_abs_grad   0.000022  w[0]   4.104 b  -5.044
# iter 340/599  loss   0.024178  avg_abs_grad   0.000017  w[0]   4.105 b  -5.046
# iter 341/599  loss   0.024178  avg_abs_grad   0.000017  w[0]   4.105 b  -5.047
# iter 360/599  loss   0.024178  avg_abs_grad   0.000013  w[0]   4.106 b  -5.048
# iter 361/599  loss   0.024178  avg_abs_grad   0.000012  w[0]   4.106 b  -5.048
# iter 380/599  loss   0.024178  avg_abs_grad   0.000010  w[0]   4.107 b  -5.050
# iter 381/599  loss   0.024178  avg_abs_grad   0.000009  w[0]   4.107 b  -5.050
# iter 400/599  loss   0.024178  avg_abs_grad   0.000007  w[0]   4.107 b  -5.051
# iter 401/599  loss   0.024178  avg_abs_grad   0.000007  w[0]   4.107 b  -5.051
# iter 420/599  loss   0.024178  avg_abs_grad   0.000005  w[0]   4.108 b  -5.051
# iter 421/599  loss   0.024178  avg_abs_grad   0.000005  w[0]   4.108 b  -5.051
# iter 440/599  loss   0.024178  avg_abs_grad   0.000004  w[0]   4.108 b  -5.052
# iter 441/599  loss   0.024178  avg_abs_grad   0.000004  w[0]   4.108 b  -5.052
# iter 460/599  loss   0.024178  avg_abs_grad   0.000003  w[0]   4.108 b  -5.052
# iter 461/599  loss   0.024178  avg_abs_grad   0.000003  w[0]   4.108 b  -5.052
# iter 480/599  loss   0.024178  avg_abs_grad   0.000002  w[0]   4.108 b  -5.053
# iter 481/599  loss   0.024178  avg_abs_grad   0.000002  w[0]   4.108 b  -5.053
# iter 500/599  loss   0.024178  avg_abs_grad   0.000002  w[0]   4.108 b  -5.053
# iter 501/599  loss   0.024178  avg_abs_grad   0.000002  w[0]   4.108 b  -5.053
# iter 520/599  loss   0.024178  avg_abs_grad   0.000001  w[0]   4.109 b  -5.053
# iter 521/599  loss   0.024178  avg_abs_grad   0.000001  w[0]   4.109 b  -5.053
# iter 540/599  loss   0.024178  avg_abs_grad   0.000001  w[0]   4.109 b  -5.053
# iter 541/599  loss   0.024178  avg_abs_grad   0.000001  w[0]   4.109 b  -5.053
# iter 560/599  loss   0.024178  avg_abs_grad   0.000001  w[0]   4.109 b  -5.053
# Done. Converged after 560 iters with step_size 4.5
# Done. Converged after 560 iters with step_size 4.5

# %% [markdown]
# ## Step 1B part two: trace plotting
#
# Edit the function below to make sure you are plotting the history of your gradient descent run.
#
# Only lines marked TODO need to be edited.
#
# Please don't mess with the styling or ylims if at all possible.
# If you find yourself messing with those, it may indicate a bug.

# %%
def make_trace_plots(mylr, figsize=(11,3),
                    loss_ylims=[-0.01, 0.2],
                    grad_ylims=[-0.01, 0.2],
                    param_ylims=[-10, 12],
                    xtick_every=100,
                    ):
    fig, axgrid = plt.subplots(
        nrows=1, ncols=3, figsize=figsize, sharex=True, sharey=False);
    loss_panel = axgrid[0]
    grad_panel = axgrid[1]
    param_panel = axgrid[2]
    try:
        xmax = np.max(mylr.trace_steps)
    except AttributeError:
        xmax = 100
    
    # Plot loss as function of iteration
    loss_panel.plot(mylr.trace_steps, mylr.trace_loss, 'm') 
    loss_panel.set_ylim(loss_ylims);
    loss_panel.set_xlabel('iter');
    loss_panel.set_ylabel('loss J');
    loss_panel.set_xticks(np.arange(0, xmax, xtick_every));
    
    # Plot L1 norm of grad as function of iteration
    grad_panel.plot(mylr.trace_steps, mylr.trace_grad_L1_norm, 'm')
    grad_panel.set_ylim(grad_ylims);
    grad_panel.set_xlabel('iter');
    grad_panel.set_ylabel('sum(abs(grad_G))')
    
    # Plot parameter values as function of iteration
    step_list = mylr.trace_steps
    w_list = [w[0] for w in mylr.trace_param]
    b_list = [w[-1] for w in mylr.trace_param]  
    param_panel.plot(step_list, w_list, 'b', label='w')
    param_panel.plot(step_list, b_list, 'r', label='b')    
    param_panel.legend(loc='upper right');
    param_panel.set_xlabel('iter');
    param_panel.set_ylim(param_ylims);
    param_panel.set_ylabel('param. val.')
    
    plt.tight_layout();

# %% [markdown]
# ## Figure 1b: Trace plots for from-zeros run

# %%
make_trace_plots(mylr_fromzeros)

# %% [markdown]
# TODO in your report: **In a brief caption**, indicate the `step_size` used and why you picked that value.

# %% [markdown]
# FYI as a bonus exercise for your own understanding, you could try calling fit using a different initialization (random), and compare the trace plots of that call to the ones above.

# %% [markdown]
# ## Step 1C: Verify your implementation matches sklearn

# %% [markdown]
# Setup numpy so we print out arrays nicely to only 3 decimal places

# %%
def pprint_float(fval):
    return '% .3f' % fval

pretty_formatter = {'float': pprint_float}
np.set_printoptions(formatter=pretty_formatter)

# %%
import sklearn.metrics
from sklearn.linear_model import LogisticRegression

row_list = list()

# Assign appropriate step_size per C
step_size_map = {
    500.0: 100,
    5.0: 1,
    0.005: 0.05
}

for C in [500.0, 5.0, 0.005]:
    sklr = LogisticRegression(C=C, max_iter=999, solver='lbfgs', random_state=0)
    sklr.fit(x_NF, y_N)
    sklr_wtil_G = np.append(sklr.coef_.ravel(), sklr.intercept_)
    sklr_loss = LogisticRegressionGradientDescent(C=C, use_base2_for_BCE=False).calc_loss(
        sklr_wtil_G, insert_final_col_of_all_ones(x_NF), y_N
    ) 
    
    # Stash sklearn values
    row_dict = {'C':C, 'method':'sklearn',
                'wtil_G':str(sklr_wtil_G),
                'loss':sklr_loss,
                'solver_status':'',
               }
    row_list.append(row_dict)    
    
    # Pick step size for this C
    step_size = step_size_map[C]
    mylr = LogisticRegressionGradientDescent(
        C=C, 
        step_size=step_size,
        use_base2_for_BCE=False,  # Using base-e ensures we match sklearn exactly
        num_iterations=999,
        verbose=True,             # You may set verbose=True to better adjust step_size
        )
    mylr.fit(x_NF, y_N)
    mylr_wtil_G = mylr.wtil_G
    mylr_loss = mylr.calc_loss(mylr_wtil_G, insert_final_col_of_all_ones(x_NF), y_N)  

    # Stash 'my code' values
    row_dict = {'C':C, 'method':'my code',
                'wtil_G':str(mylr_wtil_G),
                'loss':mylr_loss,
                'solver_status':mylr.solver_status,
               }
    row_list.append(row_dict)
    
    print("C = % 9.3f" % C)
    print(f"{mylr.solver_status} (step_size={step_size})")
# Out:
# Initializing G=2 parameters in wtil_G via recipe: zeros
# Running GD for up to 999 iters with step_size 100
# iter   0/999  loss   0.693147  avg_abs_grad   0.375000  w[0]   0.000 b   0.000
# iter   1/999  loss   2.307641  avg_abs_grad   0.077939  w[0]  75.000 b   0.000
# iter   2/999  loss   0.964518  avg_abs_grad   0.067987  w[0]  71.236 b -11.824
# iter   3/999  loss   0.456311  avg_abs_grad   0.006880  w[0]  67.536 b -21.721
# iter   4/999  loss   0.438128  avg_abs_grad   0.006709  w[0]  66.180 b -21.741
# iter   5/999  loss   0.420700  avg_abs_grad   0.006551  w[0]  64.853 b -21.756
# iter   6/999  loss   0.403985  avg_abs_grad   0.006404  w[0]  63.554 b -21.767
# iter   7/999  loss   0.387947  avg_abs_grad   0.006264  w[0]  62.281 b -21.775
# iter   8/999  loss   0.372556  avg_abs_grad   0.006130  w[0]  61.034 b -21.780
# iter   9/999  loss   0.357782  avg_abs_grad   0.006001  w[0]  59.812 b -21.785
# iter  10/999  loss   0.343598  avg_abs_grad   0.005877  w[0]  58.615 b -21.788
# iter  11/999  loss   0.329980  avg_abs_grad   0.005756  w[0]  57.442 b -21.790
# iter  12/999  loss   0.316904  avg_abs_grad   0.005638  w[0]  56.293 b -21.792
# iter  13/999  loss   0.304349  avg_abs_grad   0.005524  w[0]  55.167 b -21.794
# iter  14/999  loss   0.292292  avg_abs_grad   0.005412  w[0]  54.063 b -21.795
# iter  15/999  loss   0.280713  avg_abs_grad   0.005302  w[0]  52.982 b -21.796
# iter  16/999  loss   0.269594  avg_abs_grad   0.005195  w[0]  51.922 b -21.796
# iter  17/999  loss   0.258916  avg_abs_grad   0.005091  w[0]  50.883 b -21.797
# iter  18/999  loss   0.248661  avg_abs_grad   0.004989  w[0]  49.866 b -21.797
# iter  19/999  loss   0.238813  avg_abs_grad   0.004888  w[0]  48.868 b -21.798
# iter  20/999  loss   0.229355  avg_abs_grad   0.004790  w[0]  47.891 b -21.798
# iter  21/999  loss   0.220272  avg_abs_grad   0.004694  w[0]  46.933 b -21.798
# iter  40/999  loss   0.102222  avg_abs_grad   0.003197  w[0]  31.972 b -21.799
# iter  41/999  loss   0.098174  avg_abs_grad   0.003133  w[0]  31.333 b -21.799
# iter  60/999  loss   0.045560  avg_abs_grad   0.002134  w[0]  21.345 b -21.799
# iter  61/999  loss   0.043756  avg_abs_grad   0.002092  w[0]  20.918 b -21.799
# iter  80/999  loss   0.020314  avg_abs_grad   0.001422  w[0]  14.251 b -21.799
# iter  81/999  loss   0.019517  avg_abs_grad   0.001391  w[0]  13.967 b -21.798
# iter 100/999  loss   0.014067  avg_abs_grad   0.000614  w[0]  11.491 b -20.818
# iter 101/999  loss   0.013980  avg_abs_grad   0.000612  w[0]  11.454 b -20.732
# iter 120/999  loss   0.012424  avg_abs_grad   0.000575  w[0]  10.778 b -19.150
# iter 121/999  loss   0.012348  avg_abs_grad   0.000573  w[0]  10.743 b -19.070
# iter 140/999  loss   0.010983  avg_abs_grad   0.000538  w[0]  10.112 b -17.587
# iter 141/999  loss   0.010915  avg_abs_grad   0.000537  w[0]  10.080 b -17.511
# iter 160/999  loss   0.009717  avg_abs_grad   0.000504  w[0]   9.490 b -16.121
# iter 161/999  loss   0.009658  avg_abs_grad   0.000502  w[0]   9.460 b -16.050
# iter 180/999  loss   0.008605  avg_abs_grad   0.000472  w[0]   8.910 b -14.747
# iter 181/999  loss   0.008554  avg_abs_grad   0.000470  w[0]   8.882 b -14.680
# iter 200/999  loss   0.007630  avg_abs_grad   0.000442  w[0]   8.369 b -13.458
# iter 201/999  loss   0.007584  avg_abs_grad   0.000440  w[0]   8.342 b -13.396
# iter 220/999  loss   0.006775  avg_abs_grad   0.000413  w[0]   7.864 b -12.251
# iter 221/999  loss   0.006735  avg_abs_grad   0.000411  w[0]   7.840 b -12.193
# iter 240/999  loss   0.006031  avg_abs_grad   0.000384  w[0]   7.395 b -11.124
# iter 241/999  loss   0.005997  avg_abs_grad   0.000382  w[0]   7.373 b -11.070
# iter 260/999  loss   0.005396  avg_abs_grad   0.000351  w[0]   6.963 b -10.082
# iter 261/999  loss   0.005367  avg_abs_grad   0.000349  w[0]   6.942 b -10.032
# iter 280/999  loss   0.004878  avg_abs_grad   0.000311  w[0]   6.571 b  -9.141
# iter 281/999  loss   0.004855  avg_abs_grad   0.000308  w[0]   6.553 b  -9.098
# iter 300/999  loss   0.004497  avg_abs_grad   0.000256  w[0]   6.232 b  -8.337
# iter 301/999  loss   0.004482  avg_abs_grad   0.000252  w[0]   6.217 b  -8.301
# iter 320/999  loss   0.004267  avg_abs_grad   0.000186  w[0]   5.962 b  -7.714
# iter 321/999  loss   0.004259  avg_abs_grad   0.000182  w[0]   5.951 b  -7.688
# iter 340/999  loss   0.004161  avg_abs_grad   0.000115  w[0]   5.775 b  -7.297
# iter 341/999  loss   0.004158  avg_abs_grad   0.000112  w[0]   5.767 b  -7.281
# iter 360/999  loss   0.004126  avg_abs_grad   0.000062  w[0]   5.663 b  -7.057
# iter 361/999  loss   0.004125  avg_abs_grad   0.000060  w[0]   5.659 b  -7.049
# iter 380/999  loss   0.004116  avg_abs_grad   0.000030  w[0]   5.605 b  -6.936
# iter 381/999  loss   0.004116  avg_abs_grad   0.000029  w[0]   5.603 b  -6.932
# iter 400/999  loss   0.004114  avg_abs_grad   0.000014  w[0]   5.577 b  -6.879
# iter 401/999  loss   0.004114  avg_abs_grad   0.000013  w[0]   5.576 b  -6.877
# iter 420/999  loss   0.004114  avg_abs_grad   0.000006  w[0]   5.565 b  -6.853
# iter 421/999  loss   0.004114  avg_abs_grad   0.000006  w[0]   5.564 b  -6.852
# iter 440/999  loss   0.004114  avg_abs_grad   0.000003  w[0]   5.559 b  -6.841
# iter 441/999  loss   0.004114  avg_abs_grad   0.000003  w[0]   5.559 b  -6.841
# iter 460/999  loss   0.004114  avg_abs_grad   0.000001  w[0]   5.557 b  -6.836
# iter 461/999  loss   0.004114  avg_abs_grad   0.000001  w[0]   5.557 b  -6.836
# iter 480/999  loss   0.004114  avg_abs_grad   0.000001  w[0]   5.556 b  -6.834
# iter 481/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.556 b  -6.834
# iter 500/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.833
# iter 501/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.833
# iter 520/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.833
# iter 521/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.833
# iter 540/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.833
# iter 541/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.833
# iter 560/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.832
# iter 561/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.832
# iter 580/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.832
# iter 581/999  loss   0.004114  avg_abs_grad   0.000000  w[0]   5.555 b  -6.832
# Done. Converged after 592 iters with step_size 100
# C =   500.000
# Done. Converged after 592 iters with step_size 100 (step_size=100)
# Initializing G=2 parameters in wtil_G via recipe: zeros
# Running GD for up to 999 iters with step_size 1
# iter   0/999  loss   0.693147  avg_abs_grad   0.375000  w[0]   0.000 b   0.000
# iter   1/999  loss   0.370939  avg_abs_grad   0.177991  w[0]   0.750 b   0.000
# iter   2/999  loss   0.313478  avg_abs_grad   0.145683  w[0]   0.939 b  -0.167
# iter   3/999  loss   0.273956  avg_abs_grad   0.123916  w[0]   1.075 b  -0.323
# iter   4/999  loss   0.244604  avg_abs_grad   0.107593  w[0]   1.181 b  -0.465
# iter   5/999  loss   0.221986  avg_abs_grad   0.094770  w[0]   1.268 b  -0.593
# iter   6/999  loss   0.204119  avg_abs_grad   0.084412  w[0]   1.341 b  -0.709
# iter   7/999  loss   0.189729  avg_abs_grad   0.075876  w[0]   1.405 b  -0.814
# iter   8/999  loss   0.177955  avg_abs_grad   0.068730  w[0]   1.460 b  -0.910
# iter   9/999  loss   0.168189  avg_abs_grad   0.062667  w[0]   1.509 b  -0.999
# iter  10/999  loss   0.159993  avg_abs_grad   0.057465  w[0]   1.553 b  -1.080
# iter  11/999  loss   0.153045  avg_abs_grad   0.052959  w[0]   1.593 b  -1.155
# iter  12/999  loss   0.147101  avg_abs_grad   0.049021  w[0]   1.630 b  -1.225
# iter  13/999  loss   0.141974  avg_abs_grad   0.045553  w[0]   1.663 b  -1.289
# iter  14/999  loss   0.137522  avg_abs_grad   0.042478  w[0]   1.693 b  -1.350
# iter  15/999  loss   0.133630  avg_abs_grad   0.039735  w[0]   1.721 b  -1.407
# iter  16/999  loss   0.130207  avg_abs_grad   0.037275  w[0]   1.747 b  -1.460
# iter  17/999  loss   0.127182  avg_abs_grad   0.035056  w[0]   1.772 b  -1.511
# iter  18/999  loss   0.124495  avg_abs_grad   0.033047  w[0]   1.794 b  -1.558
# iter  19/999  loss   0.122099  avg_abs_grad   0.031219  w[0]   1.816 b  -1.603
# iter  20/999  loss   0.119952  avg_abs_grad   0.029550  w[0]   1.836 b  -1.645
# iter  21/999  loss   0.118022  avg_abs_grad   0.028021  w[0]   1.854 b  -1.686
# iter  40/999  loss   0.101340  avg_abs_grad   0.012702  w[0]   2.078 b  -2.194
# iter  41/999  loss   0.100969  avg_abs_grad   0.012275  w[0]   2.085 b  -2.212
# iter  60/999  loss   0.096986  avg_abs_grad   0.006914  w[0]   2.189 b  -2.465
# iter  61/999  loss   0.096875  avg_abs_grad   0.006728  w[0]   2.193 b  -2.475
# iter  80/999  loss   0.095563  avg_abs_grad   0.004150  w[0]   2.251 b  -2.621
# iter  81/999  loss   0.095523  avg_abs_grad   0.004052  w[0]   2.253 b  -2.627
# iter 100/999  loss   0.095024  avg_abs_grad   0.002620  w[0]   2.289 b  -2.717
# iter 101/999  loss   0.095007  avg_abs_grad   0.002562  w[0]   2.290 b  -2.721
# iter 120/999  loss   0.094802  avg_abs_grad   0.001702  w[0]   2.313 b  -2.779
# iter 121/999  loss   0.094796  avg_abs_grad   0.001666  w[0]   2.314 b  -2.782
# iter 140/999  loss   0.094707  avg_abs_grad   0.001125  w[0]   2.328 b  -2.820
# iter 141/999  loss   0.094704  avg_abs_grad   0.001103  w[0]   2.329 b  -2.821
# iter 160/999  loss   0.094665  avg_abs_grad   0.000753  w[0]   2.339 b  -2.847
# iter 161/999  loss   0.094664  avg_abs_grad   0.000738  w[0]   2.339 b  -2.848
# iter 180/999  loss   0.094646  avg_abs_grad   0.000507  w[0]   2.346 b  -2.865
# iter 181/999  loss   0.094646  avg_abs_grad   0.000497  w[0]   2.346 b  -2.866
# iter 200/999  loss   0.094638  avg_abs_grad   0.000343  w[0]   2.350 b  -2.877
# iter 201/999  loss   0.094637  avg_abs_grad   0.000337  w[0]   2.350 b  -2.878
# iter 220/999  loss   0.094634  avg_abs_grad   0.000233  w[0]   2.353 b  -2.885
# iter 221/999  loss   0.094634  avg_abs_grad   0.000229  w[0]   2.354 b  -2.886
# iter 240/999  loss   0.094632  avg_abs_grad   0.000159  w[0]   2.356 b  -2.891
# iter 241/999  loss   0.094632  avg_abs_grad   0.000156  w[0]   2.356 b  -2.891
# iter 260/999  loss   0.094631  avg_abs_grad   0.000108  w[0]   2.357 b  -2.895
# iter 261/999  loss   0.094631  avg_abs_grad   0.000106  w[0]   2.357 b  -2.895
# iter 280/999  loss   0.094631  avg_abs_grad   0.000074  w[0]   2.358 b  -2.897
# iter 281/999  loss   0.094631  avg_abs_grad   0.000072  w[0]   2.358 b  -2.898
# iter 300/999  loss   0.094631  avg_abs_grad   0.000050  w[0]   2.359 b  -2.899
# iter 301/999  loss   0.094630  avg_abs_grad   0.000049  w[0]   2.359 b  -2.899
# iter 320/999  loss   0.094630  avg_abs_grad   0.000034  w[0]   2.359 b  -2.901
# iter 321/999  loss   0.094630  avg_abs_grad   0.000034  w[0]   2.359 b  -2.901
# iter 340/999  loss   0.094630  avg_abs_grad   0.000023  w[0]   2.360 b  -2.901
# iter 341/999  loss   0.094630  avg_abs_grad   0.000023  w[0]   2.360 b  -2.901
# iter 360/999  loss   0.094630  avg_abs_grad   0.000016  w[0]   2.360 b  -2.902
# iter 361/999  loss   0.094630  avg_abs_grad   0.000016  w[0]   2.360 b  -2.902
# iter 380/999  loss   0.094630  avg_abs_grad   0.000011  w[0]   2.360 b  -2.902
# iter 381/999  loss   0.094630  avg_abs_grad   0.000011  w[0]   2.360 b  -2.902
# iter 400/999  loss   0.094630  avg_abs_grad   0.000008  w[0]   2.360 b  -2.903
# iter 401/999  loss   0.094630  avg_abs_grad   0.000007  w[0]   2.360 b  -2.903
# iter 420/999  loss   0.094630  avg_abs_grad   0.000005  w[0]   2.360 b  -2.903
# iter 421/999  loss   0.094630  avg_abs_grad   0.000005  w[0]   2.360 b  -2.903
# iter 440/999  loss   0.094630  avg_abs_grad   0.000004  w[0]   2.360 b  -2.903
# iter 441/999  loss   0.094630  avg_abs_grad   0.000003  w[0]   2.360 b  -2.903
# iter 460/999  loss   0.094630  avg_abs_grad   0.000002  w[0]   2.360 b  -2.903
# iter 461/999  loss   0.094630  avg_abs_grad   0.000002  w[0]   2.360 b  -2.903
# Done. Converged after 462 iters with step_size 1
# C =     5.000
# Done. Converged after 462 iters with step_size 1 (step_size=1)
# Initializing G=2 parameters in wtil_G via recipe: zeros
# Running GD for up to 999 iters with step_size 0.05
# iter   0/999  loss   0.693147  avg_abs_grad   0.375000  w[0]   0.000 b   0.000
# iter   1/999  loss   0.679768  avg_abs_grad   0.023968  w[0]   0.038 b   0.000
# iter   2/999  loss   0.679730  avg_abs_grad   0.006380  w[0]   0.036 b  -0.001
# iter   3/999  loss   0.679724  avg_abs_grad   0.005392  w[0]   0.036 b  -0.001
# iter   4/999  loss   0.679718  avg_abs_grad   0.005370  w[0]   0.036 b  -0.002
# iter   5/999  loss   0.679713  avg_abs_grad   0.005302  w[0]   0.036 b  -0.002
# iter   6/999  loss   0.679707  avg_abs_grad   0.005237  w[0]   0.036 b  -0.003
# iter   7/999  loss   0.679702  avg_abs_grad   0.005173  w[0]   0.036 b  -0.003
# iter   8/999  loss   0.679697  avg_abs_grad   0.005110  w[0]   0.036 b  -0.004
# iter   9/999  loss   0.679692  avg_abs_grad   0.005047  w[0]   0.036 b  -0.004
# iter  10/999  loss   0.679687  avg_abs_grad   0.004985  w[0]   0.036 b  -0.005
# iter  11/999  loss   0.679682  avg_abs_grad   0.004924  w[0]   0.036 b  -0.005
# iter  12/999  loss   0.679677  avg_abs_grad   0.004864  w[0]   0.036 b  -0.006
# iter  13/999  loss   0.679673  avg_abs_grad   0.004804  w[0]   0.036 b  -0.006
# iter  14/999  loss   0.679668  avg_abs_grad   0.004745  w[0]   0.036 b  -0.007
# iter  15/999  loss   0.679664  avg_abs_grad   0.004687  w[0]   0.036 b  -0.007
# iter  16/999  loss   0.679660  avg_abs_grad   0.004630  w[0]   0.036 b  -0.008
# iter  17/999  loss   0.679656  avg_abs_grad   0.004573  w[0]   0.036 b  -0.008
# iter  18/999  loss   0.679652  avg_abs_grad   0.004517  w[0]   0.036 b  -0.008
# iter  19/999  loss   0.679648  avg_abs_grad   0.004461  w[0]   0.036 b  -0.009
# iter  20/999  loss   0.679644  avg_abs_grad   0.004407  w[0]   0.036 b  -0.009
# iter  21/999  loss   0.679640  avg_abs_grad   0.004353  w[0]   0.036 b  -0.010
# iter  40/999  loss   0.679584  avg_abs_grad   0.003443  w[0]   0.036 b  -0.017
# iter  41/999  loss   0.679582  avg_abs_grad   0.003401  w[0]   0.036 b  -0.017
# iter  60/999  loss   0.679547  avg_abs_grad   0.002690  w[0]   0.036 b  -0.023
# iter  61/999  loss   0.679546  avg_abs_grad   0.002657  w[0]   0.036 b  -0.023
# iter  80/999  loss   0.679525  avg_abs_grad   0.002102  w[0]   0.036 b  -0.028
# iter  81/999  loss   0.679524  avg_abs_grad   0.002076  w[0]   0.036 b  -0.028
# iter 100/999  loss   0.679511  avg_abs_grad   0.001642  w[0]   0.036 b  -0.032
# iter 101/999  loss   0.679511  avg_abs_grad   0.001622  w[0]   0.036 b  -0.032
# iter 120/999  loss   0.679503  avg_abs_grad   0.001283  w[0]   0.036 b  -0.034
# iter 121/999  loss   0.679503  avg_abs_grad   0.001268  w[0]   0.036 b  -0.035
# iter 140/999  loss   0.679498  avg_abs_grad   0.001003  w[0]   0.036 b  -0.037
# iter 141/999  loss   0.679498  avg_abs_grad   0.000990  w[0]   0.036 b  -0.037
# iter 160/999  loss   0.679495  avg_abs_grad   0.000783  w[0]   0.036 b  -0.039
# iter 161/999  loss   0.679495  avg_abs_grad   0.000774  w[0]   0.036 b  -0.039
# iter 180/999  loss   0.679493  avg_abs_grad   0.000612  w[0]   0.036 b  -0.040
# iter 181/999  loss   0.679493  avg_abs_grad   0.000605  w[0]   0.036 b  -0.040
# iter 200/999  loss   0.679492  avg_abs_grad   0.000478  w[0]   0.036 b  -0.041
# iter 201/999  loss   0.679492  avg_abs_grad   0.000472  w[0]   0.036 b  -0.041
# iter 220/999  loss   0.679491  avg_abs_grad   0.000374  w[0]   0.036 b  -0.042
# iter 221/999  loss   0.679491  avg_abs_grad   0.000369  w[0]   0.036 b  -0.042
# iter 240/999  loss   0.679491  avg_abs_grad   0.000292  w[0]   0.036 b  -0.042
# iter 241/999  loss   0.679491  avg_abs_grad   0.000288  w[0]   0.036 b  -0.042
# iter 260/999  loss   0.679490  avg_abs_grad   0.000228  w[0]   0.036 b  -0.043
# iter 261/999  loss   0.679490  avg_abs_grad   0.000225  w[0]   0.036 b  -0.043
# iter 280/999  loss   0.679490  avg_abs_grad   0.000178  w[0]   0.036 b  -0.043
# iter 281/999  loss   0.679490  avg_abs_grad   0.000176  w[0]   0.036 b  -0.043
# iter 300/999  loss   0.679490  avg_abs_grad   0.000139  w[0]   0.036 b  -0.044
# iter 301/999  loss   0.679490  avg_abs_grad   0.000138  w[0]   0.036 b  -0.044
# iter 320/999  loss   0.679490  avg_abs_grad   0.000109  w[0]   0.036 b  -0.044
# iter 321/999  loss   0.679490  avg_abs_grad   0.000107  w[0]   0.036 b  -0.044
# iter 340/999  loss   0.679490  avg_abs_grad   0.000085  w[0]   0.036 b  -0.044
# iter 341/999  loss   0.679490  avg_abs_grad   0.000084  w[0]   0.036 b  -0.044
# iter 360/999  loss   0.679490  avg_abs_grad   0.000066  w[0]   0.036 b  -0.044
# iter 361/999  loss   0.679490  avg_abs_grad   0.000066  w[0]   0.036 b  -0.044
# iter 380/999  loss   0.679490  avg_abs_grad   0.000052  w[0]   0.036 b  -0.044
# Done. Converged after 380 iters with step_size 0.05
# C =     0.005
# Done. Converged after 380 iters with step_size 0.05 (step_size=0.05)

# %% [markdown]
# ## Table 1c

# %%
# Convert the rows assembed above into a pandas DataFrame
df = pd.DataFrame(row_list)

# %% [markdown]
# Pretty print the pandas data frame as an HTML table.
# You can copy this into your report.

# %%
pd.set_option('display.max_colwidth', 200)
from IPython.core.display import HTML
HTML(df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>C</th>
#       <th>method</th>
#       <th>wtil_G</th>
#       <th>loss</th>
#       <th>solver_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500.000</td>
#       <td>sklearn</td>
#       <td>[ 5.556 -6.832]</td>
#       <td>0.004114</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>500.000</td>
#       <td>my code</td>
#       <td>[ 5.555 -6.832]</td>
#       <td>0.004114</td>
#       <td>Done. Converged after 592 iters with step_size 100</td>
#     </tr>
#     <tr>
#       <td>5.000</td>
#       <td>sklearn</td>
#       <td>[ 2.360 -2.903]</td>
#       <td>0.094630</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>5.000</td>
#       <td>my code</td>
#       <td>[ 2.360 -2.903]</td>
#       <td>0.094630</td>
#       <td>Done. Converged after 462 iters with step_size 1</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>sklearn</td>
#       <td>[ 0.036 -0.045]</td>
#       <td>0.679490</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>my code</td>
#       <td>[ 0.036 -0.044]</td>
#       <td>0.679490</td>
#       <td>Done. Converged after 380 iters with step_size 0.05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If needed, here's a plain text version of the table you could also include in your report.

# %%
print(df.to_string(index=False))
# Out:
#       C  method          wtil_G     loss                                       solver_status
# 500.000 sklearn [ 5.556 -6.832] 0.004114
# 500.000 my code [ 5.555 -6.832] 0.004114  Done. Converged after 592 iters with step_size 100
#   5.000 sklearn [ 2.360 -2.903] 0.094630
#   5.000 my code [ 2.360 -2.903] 0.094630    Done. Converged after 462 iters with step_size 1
#   0.005 sklearn [ 0.036 -0.045] 0.679490
#   0.005 my code [ 0.036 -0.044] 0.679490 Done. Converged after 380 iters with step_size 0.05

# %% [markdown]
# ### Short answer 1d
#
# See instructions on webpage. Write answer in your report
