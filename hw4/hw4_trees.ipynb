# %% [markdown]
# # HW4 Trees and Forests
#
# Official instructions:
#
# https://www.cs.tufts.edu/cs/135/2025f/hw4.html
#
# This is the *starter code* notebook for Problem 2 specifically, looking at sentiment classification using bag-of-words features of product reviews.

# %%
import numpy as np
import pandas as pd
import os
import sys
import time

# %%
import sklearn.tree
import sklearn.linear_model
import sklearn.metrics
import sklearn.ensemble

# %%
# From the starter code
from pretty_print_sklearn_tree import pretty_print_sklearn_tree

# %%
# Plotting utils
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Load all data from train/valid/test

# %%
DATA_DIR = os.path.join("data_product_reviews")

# %% [markdown]
# ### Load training

# %%
x_tr_df = pd.read_csv(os.path.join(DATA_DIR, 'x_train.csv.zip'))
y_tr_df = pd.read_csv(os.path.join(DATA_DIR, 'y_train.csv'))
x_tr_NF = np.minimum(x_tr_df.values, 1.0).copy()
y_tr_N = y_tr_df.values[:,0].copy()

print("Training data")
print("x_tr_NF.shape: %s" % str(x_tr_NF.shape))
print("y_tr_N.shape : %s" % str(y_tr_N.shape))
print("mean(y_tr_N) : %.3f" % np.mean(y_tr_N))
# Out:
# Training data
# x_tr_NF.shape: (6346, 7729)
# y_tr_N.shape : (6346,)
# mean(y_tr_N) : 0.500

# %% [markdown]
# ### Load validation set

# %%
x_va_df = pd.read_csv(os.path.join(DATA_DIR, 'x_valid.csv.zip'))
y_va_df = pd.read_csv(os.path.join(DATA_DIR, 'y_valid.csv'))

x_va_TF = np.minimum(x_va_df.values, 1.0).copy()
y_va_T = y_va_df.values[:,0].copy()

print("Validation data")
print("x_va_TF.shape: %s" % str(x_va_TF.shape))
print("y_va_T.shape : %s" % str(y_va_T.shape))
print("mean(y_va_T) : %.3f" % np.mean(y_va_T))
# Out:
# Validation data
# x_va_TF.shape: (792, 7729)
# y_va_T.shape : (792,)
# mean(y_va_T) : 0.490

# %% [markdown]
# ### Load test set

# %%
x_te_df = pd.read_csv(os.path.join(DATA_DIR, 'x_test.csv.zip'))
y_te_df = pd.read_csv(os.path.join(DATA_DIR, 'y_test.csv'))

x_te_TF = np.minimum(x_te_df.values, 1.0).copy()
y_te_T = y_te_df.values[:,0].copy()

print("Heldout Test data")
print("x_te_TF.shape: %s" % str(x_te_TF.shape))
print("y_te_T.shape : %s" % str(y_te_T.shape))
print("mean(y_te_T) : %.3f" % np.mean(y_te_T))
# Out:
# Heldout Test data
# x_te_TF.shape: (793, 7729)
# y_te_T.shape : (793,)
# mean(y_te_T) : 0.515

# %% [markdown]
# ### Load vocabulary as a list of strings

# %%
vocab_list = x_tr_df.columns.tolist()

print("total vocab size", len(vocab_list))
# Out:
# total vocab size 7729

# %%
for word in vocab_list[:8]:
    print(word)
print("...")
for word in vocab_list[-8:]:
    print(word)
# Out:
# good
# great
# time
# book
# don't
# work
# i_have
# read
# ...
# never_get
# i'd_like
# loves_it
# an_author
# nomin
# could_give
# bad_but
# gap

# %% [markdown]
# ### Pack training and validation sets into big arrays (so we can use sklearn's hyperparameter search tools)

# %%
xall_LF = np.vstack([x_tr_NF, x_va_TF])
yall_L = np.hstack([y_tr_N, y_va_T])

# %%
valid_indicators_L = np.hstack([
    -1 * np.ones(y_tr_N.size), # -1 means never include this example in any test split
    0  * np.ones(y_va_T.size), #  0 means include in the first test split (we count starting at 0 in python)
    ])

# %%
# Create splitter object using Predefined Split
# Will be used later by all hyperparameter searches

my_splitter = sklearn.model_selection.PredefinedSplit(valid_indicators_L)

# %% [markdown]
# **Tip: Perform fixed validation using GridsearchCV by passing a predefined split**
#
# Although `GridsearchCV` is mostly used for cross validation (as the name implies), we can still have it perform fixed validation by passing a predefined split as the `cv` parameter when calling it. And a `PredefinedSplit` object is how we construct a predefined split. We can pass the desired splitting scheme to `PredefinedSplit` to control how the data is split into train/validation data. We will illustrate this using a simple dataset.

# %%
X_LF = np.asarray([[1, 3],
                  [4, 4],
                  [8, 2],
                  [4, 3],
                  [7, 7]])
Y_L = np.asarray([4, 8, 10, 7, 14])

# %% [markdown]
# Let's say that we want to use the examples indexed at 0, 1, and 2 as the training set and the examples indexed at 3 and 4 as the validation set. We can specify this using a `PredefinedSplit`:

# %%
splitter = sklearn.model_selection.PredefinedSplit(test_fold=[-1, -1, -1, 0, 0])

# %% [markdown]
# Here, `-1` means to never include the example at this position in any validation fold (i.e. only use them for training), and `0` means to use the example at this position in the number 0 validation fold. But since we are doing fixed validation, there is only one validation fold (number 0).
#
# By passing the defined `splitter` as the `cv` parameter into sklearn's `GridsearchCV` object, we can ask it to do fixed validation using the split we defined, instead of the default cross validation.
#
# In hyperparameter searching, `GridsearchCV` will train the models using the examples corresponding to `-1`s in `test_fold` and validate using the examples corresponding to `0`s.

# %%
for _, (train_index, test_index) in enumerate(splitter.split()):
    print(f"Training indices: {train_index}")
    print(f"Validation indices: {test_index}")
# Out:
# Training indices: [0 1 2]
# Validation indices: [3 4]

# %% [markdown]
# For more details, see the `PredefinedSplit` doc [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.PredefinedSplit.html).
#
# Now, utilize the `my_splitter` that we defined above for our sentiment classification task to perform fixed validation using `GridsearchCV` in the following problems.

# %% [markdown]
# # Decision Trees
#
# ## Step 1A: Train a simple tree with depth 3

# %%
simple_tree = sklearn.tree.DecisionTreeClassifier(
    criterion='entropy', 
    max_depth=3,
    min_samples_split=2,
    min_samples_leaf=1, 
    random_state=101)

# %% [markdown]
# ### **Fit the tree**
#
# **TODO Train on the training set** in the next coding cell

# %%
simple_tree.fit(x_tr_NF, y_tr_N)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=101)

# %% [markdown]
# ### **Figure 1: Print Tree**
#
# Use a helper function from the starter code

# %%
pretty_print_sklearn_tree(simple_tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 15 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    8 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['waste'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.422 (4199 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.033 (210 total training examples)
#     N Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.903 (277 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.429 (14 total training examples)
#   N Decision: X['return'] <= 0.50?
#     Y Decision: X['bad'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.745 (1413 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.415 (142 total training examples)
#     N Decision: X['in_all'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.214 (84 total training examples)
#       N Leaf: p(y=1 | this leaf) = 1.000 (7 total training examples)

# %% [markdown]
# ## 1B : Find best Decision Tree with grid search

# %%
# Construct the default predictor
# Any hyperparameters here may be overridden by the hyperparameter grid

base_tree = sklearn.tree.DecisionTreeClassifier(
    criterion='entropy',
    max_depth=8,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=101,
    )

# %%
tree_hyperparameter_grid_by_name = dict(
    max_depth=[2, 8, 32, 128],
    min_samples_leaf=[1, 3, 9],
    random_state = [101],
    )

# %% [markdown]
# **TODO Build the Grid Search** in the next coding cell
#
# Follow the 1B instructions carefully:
#
# * Set `scoring='balanced_accuracy'`, since our target metric is balanced accuracy
# * Set `cv=my_splitter` (as in starter code), so you can use the predefined split we defined earlier.
# * Set `return_train_score=True`, since we want training set scores as well as valdiation set scores (which will be called 'test' by the searcher)
# * Set `refit=False`, because we only want fits on `x_tr_NF`

# %%
tree_grid_searcher = sklearn.model_selection.GridSearchCV(
    estimator=base_tree,
    param_grid=tree_hyperparameter_grid_by_name,
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False
)

# %% [markdown]
# ### Do the search!

# %%
start_time_sec = time.time()
tree_grid_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec

# %% [markdown]
# ### Build dataframe of results
#
# Move the results of grid search into a nice pandas data frame.

# %%
if hasattr(tree_grid_searcher, 'cv_results_'):
    # Will execute if you called fit on tree_grid_searcher succesfully
    tree_search_results_df = pd.DataFrame(tree_grid_searcher.cv_results_).copy()
    print("Grid search of %3d configurations done after %6.1f sec" % (
        tree_search_results_df.shape[0], elapsed_time_sec))
# Out:
# Grid search of  12 configurations done after  103.9 sec

# %% [markdown]
# ### Display search results
#
# This block will make a pretty printed table of the results of your grid search

# %%
if hasattr(tree_grid_searcher, 'cv_results_'):
    pd.set_option('display.precision', 4)
    tree_keys = ['param_max_depth', 'param_min_samples_leaf']
    tree_search_results_df.sort_values(tree_keys, inplace=True)
    tree_search_results_df[tree_keys + ['mean_train_score', 'mean_test_score', 'rank_test_score', 'mean_fit_time']]

# %%
print("Printing a dict of the best hyperparameters")
try:
    print(tree_grid_searcher.best_params_)
except AttributeError:
    print("AttributeError happens if you did not complete earlier 'Do the search' todo")
# Out:
# Printing a dict of the best hyperparameters
# {'max_depth': 128, 'min_samples_leaf': 9, 'random_state': 101}

# %% [markdown]
# ### Build the best decision tree

# %% [markdown]
# **TODO Build the Best Tree on the training set** in the next coding cell
#
# This is necessary so you have the specific best performing tree in your workspace.
#
# Although you fit many trees in the search, they were not stored, so we need to recreate the best one.
#
# Hint: Just feed the best hyperparameters as keyword args to construct the tree and fit it to the training data.

# %%
best_tree = base_tree.set_params(**tree_grid_searcher.best_params_)
best_tree.fit(x_tr_NF, y_tr_N)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=128, min_samples_leaf=9,
#                        random_state=101)

# %% [markdown]
# ### Interpret the best decision tree

# %%
pretty_print_sklearn_tree(best_tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 775 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    2 are leaves
# - depth   4 has   12 nodes, of which    3 are leaves
# - depth   5 has   18 nodes, of which    6 are leaves
# - depth   6 has   24 nodes, of which   14 are leaves
# - depth   7 has   20 nodes, of which    8 are leaves
# - depth   8 has   24 nodes, of which    9 are leaves
# - depth   9 has   30 nodes, of which   18 are leaves
# - depth  10 has   24 nodes, of which    8 are leaves
# - depth  11 has   32 nodes, of which   17 are leaves
# - depth  12 has   30 nodes, of which   16 are leaves
# - depth  13 has   28 nodes, of which   15 are leaves
# - depth  14 has   26 nodes, of which   13 are leaves
# - depth  15 has   26 nodes, of which   15 are leaves
# - depth  16 has   22 nodes, of which   10 are leaves
# - depth  17 has   24 nodes, of which   11 are leaves
# - depth  18 has   26 nodes, of which   14 are leaves
# - depth  19 has   24 nodes, of which   17 are leaves
# - depth  20 has   14 nodes, of which    7 are leaves
# - depth  21 has   14 nodes, of which    6 are leaves
# - depth  22 has   16 nodes, of which    8 are leaves
# - depth  23 has   16 nodes, of which    8 are leaves
# - depth  24 has   16 nodes, of which    9 are leaves
# - depth  25 has   14 nodes, of which   10 are leaves
# - depth  26 has    8 nodes, of which    3 are leaves
# - depth  27 has   10 nodes, of which    3 are leaves
# - depth  28 has   14 nodes, of which    6 are leaves
# - depth  29 has   16 nodes, of which   10 are leaves
# - depth  30 has   12 nodes, of which    8 are leaves
# - depth  31 has    8 nodes, of which    3 are leaves
# - depth  32 has   10 nodes, of which    3 are leaves
# - depth  33 has   14 nodes, of which    9 are leaves
# - depth  34 has   10 nodes, of which    6 are leaves
# - depth  35 has    8 nodes, of which    4 are leaves
# - depth  36 has    8 nodes, of which    5 are leaves
# - depth  37 has    6 nodes, of which    3 are leaves
# - depth  38 has    6 nodes, of which    3 are leaves
# - depth  39 has    6 nodes, of which    3 are leaves
# - depth  40 has    6 nodes, of which    3 are leaves
# - depth  41 has    6 nodes, of which    3 are leaves
# - depth  42 has    6 nodes, of which    4 are leaves
# - depth  43 has    4 nodes, of which    2 are leaves
# - depth  44 has    4 nodes, of which    1 are leaves
# - depth  45 has    6 nodes, of which    4 are leaves
# - depth  46 has    4 nodes, of which    2 are leaves
# - depth  47 has    4 nodes, of which    1 are leaves
# - depth  48 has    6 nodes, of which    5 are leaves
# - depth  49 has    2 nodes, of which    1 are leaves
# - depth  50 has    2 nodes, of which    0 are leaves
# - depth  51 has    4 nodes, of which    2 are leaves
# - depth  52 has    4 nodes, of which    3 are leaves
# - depth  53 has    2 nodes, of which    1 are leaves
# - depth  54 has    2 nodes, of which    1 are leaves
# - depth  55 has    2 nodes, of which    1 are leaves
# - depth  56 has    2 nodes, of which    1 are leaves
# - depth  57 has    2 nodes, of which    1 are leaves
# - depth  58 has    2 nodes, of which    1 are leaves
# - depth  59 has    2 nodes, of which    1 are leaves
# - depth  60 has    2 nodes, of which    1 are leaves
# - depth  61 has    2 nodes, of which    1 are leaves
# - depth  62 has    2 nodes, of which    0 are leaves
# - depth  63 has    4 nodes, of which    2 are leaves
# - depth  64 has    4 nodes, of which    3 are leaves
# - depth  65 has    2 nodes, of which    1 are leaves
# - depth  66 has    2 nodes, of which    1 are leaves
# - depth  67 has    2 nodes, of which    0 are leaves
# - depth  68 has    4 nodes, of which    2 are leaves
# - depth  69 has    4 nodes, of which    2 are leaves
# - depth  70 has    4 nodes, of which    3 are leaves
# - depth  71 has    2 nodes, of which    1 are leaves
# - depth  72 has    2 nodes, of which    1 are leaves
# - depth  73 has    2 nodes, of which    1 are leaves
# - depth  74 has    2 nodes, of which    0 are leaves
# - depth  75 has    4 nodes, of which    3 are leaves
# - depth  76 has    2 nodes, of which    1 are leaves
# - depth  77 has    2 nodes, of which    1 are leaves
# - depth  78 has    2 nodes, of which    1 are leaves
# - depth  79 has    2 nodes, of which    1 are leaves
# - depth  80 has    2 nodes, of which    0 are leaves
# - depth  81 has    4 nodes, of which    3 are leaves
# - depth  82 has    2 nodes, of which    1 are leaves
# - depth  83 has    2 nodes, of which    1 are leaves
# - depth  84 has    2 nodes, of which    1 are leaves
# - depth  85 has    2 nodes, of which    1 are leaves
# - depth  86 has    2 nodes, of which    1 are leaves
# - depth  87 has    2 nodes, of which    1 are leaves
# - depth  88 has    2 nodes, of which    2 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['waste'] <= 0.50?
#       Y Decision: X['disappoint'] <= 0.50?
#         Y Decision: X['love'] <= 0.50?
#           Y Decision: X['easy_to'] <= 0.50?
#             Y Decision: X['bad'] <= 0.50?
#               Y Decision: X['poor'] <= 0.50?
#                 Y Decision: X['return'] <= 0.50?
#                   Y Decision: X['bore'] <= 0.50?
#                     Y Decision: X['the_best'] <= 0.50?
#                       Y Decision: X['worst'] <= 0.50?
#                         Y Decision: X['perfect'] <= 0.50?
#                           Y Decision: X['a_must'] <= 0.50?
#                             Y Decision: X['highly_recommend'] <= 0.50?
#                               Y Decision: X['enjoy'] <= 0.50?
#                                 Y Decision: X['not_work'] <= 0.50?
#                                   Y Decision: X['amaz'] <= 0.50?
#                                     Y Decision: X['not_recommend'] <= 0.50?
#                                       Y Decision: X['good'] <= 0.50?
#                                         Y Decision: X['this_item'] <= 0.50?
#                                           Y Decision: X['loved'] <= 0.50?
#                                             Y Decision: X['univers'] <= 0.50?
#                                               Y Decision: X['well_worth'] <= 0.50?
#                                                 Y Decision: X['impressed_with'] <= 0.50?
#                                                   Y Decision: X['back'] <= 0.50?
#                                                     Y Decision: X['the_job'] <= 0.50?
#                                                       Y Decision: X['easy'] <= 0.50?
#                                                         Y Decision: X['lover'] <= 0.50?
#                                                           Y Decision: X['your_money'] <= 0.50?
#                                                             Y Decision: X['beauti'] <= 0.50?
#                                                               Y Decision: X['knowledg'] <= 0.50?
#                                                                 Y Decision: X['minut'] <= 0.50?
#                                                                   Y Decision: X['wonder'] <= 0.50?
#                                                                     Y Decision: X['when_i'] <= 0.50?
#                                                                       Y Decision: X['fantast'] <= 0.50?
#                                                                         Y Decision: X['the_market'] <= 0.50?
#                                                                           Y Decision: X['years'] <= 0.50?
#                                                                             Y Decision: X['total'] <= 0.50?
#                                                                               Y Decision: X['imposs'] <= 0.50?
#                                                                                 Y Decision: X['for_<num>'] <= 0.50?
#                                                                                   Y Decision: X['not_what'] <= 0.50?
#                                                                                     Y Decision: X['death'] <= 0.50?
#                                                                                       Y Decision: X['as_well'] <= 0.50?
#                                                                                         Y Decision: X['stay'] <= 0.50?
#                                                                                           Y Decision: X['space'] <= 0.50?
#                                                                                             Y Decision: X['a_very'] <= 0.50?
#                                                                                               Y Decision: X['movi'] <= 0.50?
#                                                                                                 Y Decision: X['thin'] <= 0.50?
#                                                                                                   Y Decision: X['i_bought'] <= 0.50?
#                                                                                                     Y Decision: X['works'] <= 0.50?
#                                                                                                       Y Decision: X['satisfi'] <= 0.50?
#                                                                                                         Y Decision: X['is_just'] <= 0.50?
#                                                                                                           Y Decision: X['hate'] <= 0.50?
#                                                                                                             Y Decision: X['classic'] <= 0.50?
#                                                                                                               Y Decision: X['would_not'] <= 0.50?
#                                                                                                                 Y Decision: X['trying_to'] <= 0.50?
#                                                                                                                   Y Decision: X['person'] <= 0.50?
#                                                                                                                     Y Decision: X['when_the'] <= 0.50?
#                                                                                                                       Y Decision: X['is_very'] <= 0.50?
#                                                                                                                         Y Decision: X['that_you'] <= 0.50?
#                                                                                                                           Y Decision: X['make'] <= 0.50?
#                                                                                                                             Y Decision: X['the_same'] <= 0.50?
#                                                                                                                               Y Decision: X['unit'] <= 0.50?
#                                                                                                                                 Y Decision: X['qualiti'] <= 0.50?
#                                                                                                                                   Y Decision: X['one_of'] <= 0.50?
#                                                                                                                                     Y Decision: X['movie'] <= 0.50?
#                                                                                                                                       Y Decision: X['about_the'] <= 0.50?
#                                                                                                                                         Y Decision: X['month'] <= 0.50?
#                                                                                                                                           Y Decision: X['made'] <= 0.50?
#                                                                                                                                             Y Decision: X['does_not'] <= 0.50?
#                                                                                                                                               Y Decision: X['write'] <= 0.50?
#                                                                                                                                                 Y Decision: X['hard'] <= 0.50?
#                                                                                                                                                   Y Decision: X['time'] <= 0.50?
#                                                                                                                                                     Y Decision: X['give'] <= 0.50?
#                                                                                                                                                       Y Decision: X['full'] <= 0.50?
#                                                                                                                                                         Y Decision: X['review'] <= 0.50?
#                                                                                                                                                           Y Decision: X['put'] <= 0.50?
#                                                                                                                                                             Y Decision: X['receiv'] <= 0.50?
#                                                                                                                                                               Y Decision: X['i_have'] <= 0.50?
#                                                                                                                                                                 Y Decision: X['work'] <= 0.50?
#                                                                                                                                                                   Y Decision: X['book_is'] <= 0.50?
#                                                                                                                                                                     Y Decision: X['this_book'] <= 0.50?
#                                                                                                                                                                       Y Decision: X['book'] <= 0.50?
#                                                                                                                                                                         Y Decision: X['problem'] <= 0.50?
#                                                                                                                                                                           Y Decision: X['don't'] <= 0.50?
#                                                                                                                                                                             Y Decision: X['buy'] <= 0.50?
#                                                                                                                                                                               Y Decision: X['product'] <= 0.50?
#                                                                                                                                                                                 Y Leaf: p(y=1 | this leaf) = 0.488 (82 total training examples)
#                                                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.500 (12 total training examples)
#                                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.357 (14 total training examples)
#                                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.600 (10 total training examples)
#                                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.364 (11 total training examples)
#                                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.273 (22 total training examples)
#                                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.733 (15 total training examples)
#                                                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.250 (16 total training examples)
#                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.200 (15 total training examples)
#                                                                                                                                                                 N Decision: X['read'] <= 0.50?
#                                                                                                                                                                   Y Leaf: p(y=1 | this leaf) = 0.647 (17 total training examples)
#                                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.700 (10 total training examples)
#                                                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#                                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#                                                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.176 (17 total training examples)
#                                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.727 (11 total training examples)
#                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.154 (13 total training examples)
#                                                                                                                                                     N Decision: X['time_i'] <= 0.50?
#                                                                                                                                                       Y Leaf: p(y=1 | this leaf) = 0.188 (16 total training examples)
#                                                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.222 (9 total training examples)
#                                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.727 (11 total training examples)
#                                                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.091 (11 total training examples)
#                                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.688 (16 total training examples)
#                                                                                                                                           N Decision: X['<num>_months'] <= 0.50?
#                                                                                                                                             Y Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#                                                                                                                                             N Leaf: p(y=1 | this leaf) = 0.200 (10 total training examples)
#                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.778 (9 total training examples)
#                                                                                                                                       N Decision: X['watch'] <= 0.50?
#                                                                                                                                         Y Decision: X['this_movie'] <= 0.50?
#                                                                                                                                           Y Leaf: p(y=1 | this leaf) = 0.231 (13 total training examples)
#                                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.300 (10 total training examples)
#                                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.071 (14 total training examples)
#                                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.769 (13 total training examples)
#                                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.733 (15 total training examples)
#                                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.083 (12 total training examples)
#                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.130 (23 total training examples)
#                                                                                                                             N Decision: X['if_you'] <= 0.50?
#                                                                                                                               Y Decision: X['to_make'] <= 0.50?
#                                                                                                                                 Y Leaf: p(y=1 | this leaf) = 0.310 (29 total training examples)
#                                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.125 (16 total training examples)
#                                                                                                                               N Leaf: p(y=1 | this leaf) = 0.000 (11 total training examples)
#                                                                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (13 total training examples)
#                                                                                                                         N Leaf: p(y=1 | this leaf) = 0.733 (15 total training examples)
#                                                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                                                                                                     N Leaf: p(y=1 | this leaf) = 0.769 (13 total training examples)
#                                                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                                                                                                 N Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                                                                                                               N Leaf: p(y=1 | this leaf) = 0.750 (16 total training examples)
#                                                                                                             N Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                                                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (14 total training examples)
#                                                                                                         N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                                                                                       N Decision: X['it_works'] <= 0.50?
#                                                                                                         Y Leaf: p(y=1 | this leaf) = 0.571 (28 total training examples)
#                                                                                                         N Leaf: p(y=1 | this leaf) = 0.750 (12 total training examples)
#                                                                                                     N Decision: X['bought_this'] <= 0.50?
#                                                                                                       Y Leaf: p(y=1 | this leaf) = 0.111 (18 total training examples)
#                                                                                                       N Leaf: p(y=1 | this leaf) = 0.133 (15 total training examples)
#                                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (14 total training examples)
#                                                                                                 N Leaf: p(y=1 | this leaf) = 0.750 (16 total training examples)
#                                                                                               N Decision: X['book'] <= 0.50?
#                                                                                                 Y Leaf: p(y=1 | this leaf) = 0.632 (19 total training examples)
#                                                                                                 N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#                                                                                             N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)
#                                                                                           N Leaf: p(y=1 | this leaf) = 0.045 (22 total training examples)
#                                                                                         N Decision: X['this_book'] <= 0.50?
#                                                                                           Y Leaf: p(y=1 | this leaf) = 0.750 (20 total training examples)
#                                                                                           N Leaf: p(y=1 | this leaf) = 0.545 (11 total training examples)
#                                                                                       N Leaf: p(y=1 | this leaf) = 0.000 (12 total training examples)
#                                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (12 total training examples)
#                                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (12 total training examples)
#                                                                                 N Leaf: p(y=1 | this leaf) = 0.000 (13 total training examples)
#                                                                               N Leaf: p(y=1 | this leaf) = 0.000 (18 total training examples)
#                                                                             N Decision: X['and_i'] <= 0.50?
#                                                                               Y Decision: X['<year>'] <= 0.50?
#                                                                                 Y Decision: X['read'] <= 0.50?
#                                                                                   Y Decision: X['<num>_years'] <= 0.50?
#                                                                                     Y Leaf: p(y=1 | this leaf) = 0.444 (18 total training examples)
#                                                                                     N Leaf: p(y=1 | this leaf) = 0.400 (15 total training examples)
#                                                                                   N Leaf: p(y=1 | this leaf) = 0.667 (9 total training examples)
#                                                                                 N Leaf: p(y=1 | this leaf) = 0.700 (10 total training examples)
#                                                                               N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)
#                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (13 total training examples)
#                                                                         N Leaf: p(y=1 | this leaf) = 0.846 (13 total training examples)
#                                                                       N Decision: X['i_would'] <= 0.50?
#                                                                         Y Decision: X['put'] <= 0.50?
#                                                                           Y Decision: X['i_was'] <= 0.50?
#                                                                             Y Leaf: p(y=1 | this leaf) = 0.067 (15 total training examples)
#                                                                             N Leaf: p(y=1 | this leaf) = 0.083 (12 total training examples)
#                                                                           N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                                                         N Leaf: p(y=1 | this leaf) = 0.333 (9 total training examples)
#                                                                     N Leaf: p(y=1 | this leaf) = 0.700 (30 total training examples)
#                                                                   N Decision: X['movie'] <= 0.50?
#                                                                     Y Decision: X['<num>_minutes'] <= 0.50?
#                                                                       Y Leaf: p(y=1 | this leaf) = 0.200 (10 total training examples)
#                                                                       N Leaf: p(y=1 | this leaf) = 0.077 (13 total training examples)
#                                                                     N Leaf: p(y=1 | this leaf) = 0.000 (10 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.857 (14 total training examples)
#                                                               N Decision: X['buy'] <= 0.50?
#                                                                 Y Decision: X['read'] <= 0.50?
#                                                                   Y Leaf: p(y=1 | this leaf) = 0.786 (14 total training examples)
#                                                                   N Leaf: p(y=1 | this leaf) = 0.900 (10 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.333 (9 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.000 (17 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.818 (22 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 1.000 (12 total training examples)
#                                                     N Decision: X['interest'] <= 0.50?
#                                                       Y Decision: X['movie'] <= 0.50?
#                                                         Y Decision: X['i'm'] <= 0.50?
#                                                           Y Decision: X['product'] <= 0.50?
#                                                             Y Decision: X['send'] <= 0.50?
#                                                               Y Decision: X['time'] <= 0.50?
#                                                                 Y Decision: X['back_to'] <= 0.50?
#                                                                   Y Decision: X['i_have'] <= 0.50?
#                                                                     Y Leaf: p(y=1 | this leaf) = 0.258 (31 total training examples)
#                                                                     N Leaf: p(y=1 | this leaf) = 0.100 (10 total training examples)
#                                                                   N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.417 (12 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 0.000 (11 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.000 (14 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.000 (19 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.556 (9 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 0.667 (9 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 1.000 (11 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.938 (16 total training examples)
#                                             N Decision: X['this_book'] <= 0.50?
#                                               Y Decision: X['i_loved'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 0.667 (12 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#                                           N Decision: X['i_have'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.000 (27 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#                                         N Decision: X['bit'] <= 0.50?
#                                           Y Decision: X['going_to'] <= 0.50?
#                                             Y Decision: X['peopl'] <= 0.50?
#                                               Y Decision: X['send'] <= 0.50?
#                                                 Y Decision: X['pleas'] <= 0.50?
#                                                   Y Decision: X['power'] <= 0.50?
#                                                     Y Decision: X['very_good'] <= 0.50?
#                                                       Y Decision: X['hard'] <= 0.50?
#                                                         Y Decision: X['not_a'] <= 0.50?
#                                                           Y Decision: X['good_but'] <= 0.50?
#                                                             Y Decision: X['half'] <= 0.50?
#                                                               Y Decision: X['product'] <= 0.50?
#                                                                 Y Decision: X['pay'] <= 0.50?
#                                                                   Y Decision: X['back'] <= 0.50?
#                                                                     Y Decision: X['when_i'] <= 0.50?
#                                                                       Y Decision: X['nice'] <= 0.50?
#                                                                         Y Decision: X['the_end'] <= 0.50?
#                                                                           Y Decision: X['works'] <= 0.50?
#                                                                             Y Decision: X['the_first'] <= 0.50?
#                                                                               Y Decision: X['time'] <= 0.50?
#                                                                                 Y Decision: X['movie'] <= 0.50?
#                                                                                   Y Decision: X['sound'] <= 0.50?
#                                                                                     Y Decision: X['as_well'] <= 0.50?
#                                                                                       Y Decision: X['read'] <= 0.50?
#                                                                                         Y Decision: X['if_you'] <= 0.50?
#                                                                                           Y Decision: X['qualiti'] <= 0.50?
#                                                                                             Y Decision: X['a_good'] <= 0.50?
#                                                                                               Y Decision: X['book'] <= 0.50?
#                                                                                                 Y Leaf: p(y=1 | this leaf) = 0.615 (26 total training examples)
#                                                                                                 N Leaf: p(y=1 | this leaf) = 0.636 (11 total training examples)
#                                                                                               N Leaf: p(y=1 | this leaf) = 0.545 (11 total training examples)
#                                                                                             N Leaf: p(y=1 | this leaf) = 0.727 (11 total training examples)
#                                                                                           N Leaf: p(y=1 | this leaf) = 0.444 (9 total training examples)
#                                                                                         N Leaf: p(y=1 | this leaf) = 0.364 (11 total training examples)
#                                                                                       N Leaf: p(y=1 | this leaf) = 0.778 (9 total training examples)
#                                                                                     N Leaf: p(y=1 | this leaf) = 0.333 (9 total training examples)
#                                                                                   N Leaf: p(y=1 | this leaf) = 0.389 (18 total training examples)
#                                                                                 N Leaf: p(y=1 | this leaf) = 0.867 (15 total training examples)
#                                                                               N Leaf: p(y=1 | this leaf) = 0.273 (11 total training examples)
#                                                                             N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                                                           N Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#                                                                         N Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#                                                                       N Leaf: p(y=1 | this leaf) = 0.333 (18 total training examples)
#                                                                     N Leaf: p(y=1 | this leaf) = 0.182 (11 total training examples)
#                                                                   N Leaf: p(y=1 | this leaf) = 0.100 (10 total training examples)
#                                                                 N Decision: X['good_product'] <= 0.50?
#                                                                   Y Leaf: p(y=1 | this leaf) = 0.769 (13 total training examples)
#                                                                   N Leaf: p(y=1 | this leaf) = 0.909 (11 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 0.182 (11 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.167 (12 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.211 (19 total training examples)
#                                                         N Decision: X['hard_to'] <= 0.50?
#                                                           Y Leaf: p(y=1 | this leaf) = 0.222 (9 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#                                                       N Decision: X['book'] <= 0.50?
#                                                         Y Decision: X['product'] <= 0.50?
#                                                           Y Decision: X['a_very'] <= 0.50?
#                                                             Y Leaf: p(y=1 | this leaf) = 0.867 (15 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.846 (13 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.778 (9 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.444 (9 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 1.000 (12 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 1.000 (13 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                               N Decision: X['film'] <= 0.50?
#                                                 Y Decision: X['thing'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 0.318 (22 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.200 (10 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.091 (11 total training examples)
#                                             N Decision: X['don't'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.100 (10 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.000 (9 total training examples)
#                                           N Decision: X['work'] <= 0.50?
#                                             Y Decision: X['if_you'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.917 (12 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.000 (26 total training examples)
#                                     N Decision: X['one_of'] <= 0.50?
#                                       Y Decision: X['thing'] <= 0.50?
#                                         Y Decision: X['book'] <= 0.50?
#                                           Y Leaf: p(y=1 | this leaf) = 0.826 (23 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.538 (13 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 1.000 (11 total training examples)
#                                   N Decision: X['bought'] <= 0.50?
#                                     Y Decision: X['i_have'] <= 0.50?
#                                       Y Leaf: p(y=1 | this leaf) = 0.000 (31 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.222 (9 total training examples)
#                                 N Decision: X['i_would'] <= 0.50?
#                                   Y Decision: X['i_was'] <= 0.50?
#                                     Y Decision: X['feel'] <= 0.50?
#                                       Y Decision: X['dvd'] <= 0.50?
#                                         Y Decision: X['found'] <= 0.50?
#                                           Y Decision: X['don't'] <= 0.50?
#                                             Y Decision: X['charact'] <= 0.50?
#                                               Y Decision: X['i_have'] <= 0.50?
#                                                 Y Decision: X['book'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 0.800 (20 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.727 (11 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.600 (10 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 1.000 (10 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.455 (11 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.467 (15 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.273 (11 total training examples)
#                               N Decision: X['i_would'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 1.000 (20 total training examples)
# ...
#                     N Leaf: p(y=1 | this leaf) = 0.818 (11 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.778 (9 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.833 (18 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.727 (11 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.722 (18 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.556 (9 total training examples)
#         N Leaf: p(y=1 | this leaf) = 0.500 (12 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.429 (14 total training examples)
#   N Decision: X['return'] <= 0.50?
#     Y Decision: X['bad'] <= 0.50?
#       Y Decision: X['disappoint'] <= 0.50?
#         Y Decision: X['worst'] <= 0.50?
#           Y Decision: X['great_but'] <= 0.50?
#             Y Decision: X['love'] <= 0.50?
#               Y Decision: X['horribl'] <= 0.50?
#                 Y Decision: X['terribl'] <= 0.50?
#                   Y Decision: X['start'] <= 0.50?
#                     Y Decision: X['is_not'] <= 0.50?
#                       Y Decision: X['bore'] <= 0.50?
#                         Y Decision: X['price'] <= 0.50?
#                           Y Decision: X['work'] <= 0.50?
#                             Y Decision: X['poor'] <= 0.50?
#                               Y Decision: X['buy_the'] <= 0.50?
#                                 Y Decision: X['doesn't'] <= 0.50?
#                                   Y Decision: X['write'] <= 0.50?
#                                     Y Decision: X['clean'] <= 0.50?
#                                       Y Decision: X['rest'] <= 0.50?
#                                         Y Decision: X['compared_to'] <= 0.50?
#                                           Y Decision: X['one_of'] <= 0.50?
#                                             Y Decision: X['the_book'] <= 0.50?
#                                               Y Decision: X['peopl'] <= 0.50?
#                                                 Y Decision: X['i_don't'] <= 0.50?
#                                                   Y Decision: X['at_all'] <= 0.50?
#                                                     Y Decision: X['i'm'] <= 0.50?
#                                                       Y Decision: X['most_of'] <= 0.50?
#                                                         Y Decision: X['read'] <= 0.50?
#                                                           Y Decision: X['month'] <= 0.50?
#                                                             Y Decision: X['was_great'] <= 0.50?
#                                                               Y Decision: X['sound'] <= 0.50?
#                                                                 Y Decision: X['didn't'] <= 0.50?
#                                                                   Y Decision: X['this_dvd'] <= 0.50?
#                                                                     Y Decision: X['expect'] <= 0.50?
#                                                                       Y Decision: X['all_the'] <= 0.50?
#                                                                         Y Leaf: p(y=1 | this leaf) = 1.000 (195 total training examples)
#                                                                         N Leaf: p(y=1 | this leaf) = 0.938 (16 total training examples)
#                                                                       N Leaf: p(y=1 | this leaf) = 0.900 (10 total training examples)
#                                                                     N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                                                   N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                                                 N Decision: X['qualiti'] <= 0.50?
#                                                                   Y Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                                                   N Leaf: p(y=1 | this leaf) = 0.900 (10 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.769 (13 total training examples)
#                                                           N Decision: X['a_great'] <= 0.50?
#                                                             Y Leaf: p(y=1 | this leaf) = 0.786 (14 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.700 (10 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 0.722 (18 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.556 (9 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.615 (13 total training examples)
#                                                 N Decision: X['a_great'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 0.667 (9 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.700 (10 total training examples)
#                                               N Decision: X['this_book'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 0.647 (17 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.786 (14 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 1.000 (41 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.556 (9 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.545 (11 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 1.000 (32 total training examples)
#                                     N Decision: X['a_great'] <= 0.50?
#                                       Y Leaf: p(y=1 | this leaf) = 0.429 (14 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                                   N Decision: X['good'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.542 (24 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.222 (9 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.273 (11 total training examples)
#                             N Decision: X['stop'] <= 0.50?
#                               Y Decision: X['month'] <= 0.50?
#                                 Y Decision: X['i_had'] <= 0.50?
#                                   Y Decision: X['you_can'] <= 0.50?
#                                     Y Decision: X['i'm'] <= 0.50?
#                                       Y Decision: X['book_is'] <= 0.50?
#                                         Y Decision: X['a_great'] <= 0.50?
#                                           Y Decision: X['don't'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.800 (30 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.700 (10 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.636 (22 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.462 (13 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 1.000 (9 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (11 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.312 (16 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.200 (10 total training examples)
#                           N Decision: X['times'] <= 0.50?
#                             Y Decision: X['found'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 1.000 (116 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.778 (9 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.583 (12 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.231 (13 total training examples)
#                       N Decision: X['compar'] <= 0.50?
#                         Y Decision: X['doesn't'] <= 0.50?
#                           Y Decision: X['good'] <= 0.50?
#                             Y Decision: X['if_you'] <= 0.50?
#                               Y Decision: X['a_great'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.474 (19 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.600 (15 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.818 (11 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.882 (17 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.333 (12 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.222 (9 total training examples)
#                     N Decision: X['find'] <= 0.50?
#                       Y Decision: X['to_get'] <= 0.50?
#                         Y Decision: X['don't'] <= 0.50?
#                           Y Decision: X['book'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 0.500 (20 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.769 (13 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.333 (12 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.182 (11 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.846 (13 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.154 (13 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.091 (11 total training examples)
#               N Decision: X['books'] <= 0.50?
#                 Y Decision: X['love_it'] <= 0.50?
#                   Y Decision: X['story'] <= 0.50?
#                     Y Decision: X['clean'] <= 0.50?
#                       Y Decision: X['book'] <= 0.50?
#                         Y Decision: X['life'] <= 0.50?
#                           Y Decision: X['a_great'] <= 0.50?
#                             Y Decision: X['is_great'] <= 0.50?
#                               Y Decision: X['doesn't'] <= 0.50?
#                                 Y Decision: X['time'] <= 0.50?
#                                   Y Decision: X['don't'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.895 (19 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.778 (9 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.600 (10 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (12 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (27 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.600 (10 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (16 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (22 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (27 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (42 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.643 (14 total training examples)
#             N Decision: X['years'] <= 0.50?
#               Y Decision: X['works'] <= 0.50?
#                 Y Decision: X['good'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 0.421 (19 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.545 (11 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.727 (11 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.091 (11 total training examples)
#           N Decision: X['read'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 0.333 (12 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.067 (15 total training examples)
#         N Decision: X['be_disappointed'] <= 0.50?
#           Y Decision: X['don't'] <= 0.50?
#             Y Decision: X['review'] <= 0.50?
#               Y Decision: X['product'] <= 0.50?
#                 Y Decision: X['and_i'] <= 0.50?
#                   Y Decision: X['a_great'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.412 (17 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.643 (14 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.083 (12 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (13 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.900 (10 total training examples)
#       N Decision: X['the_best'] <= 0.50?
#         Y Decision: X['dvd'] <= 0.50?
#           Y Decision: X['i_love'] <= 0.50?
#             Y Decision: X['poor'] <= 0.50?
#               Y Decision: X['make'] <= 0.50?
#                 Y Decision: X['includ'] <= 0.50?
#                   Y Decision: X['work'] <= 0.50?
#                     Y Decision: X['movie'] <= 0.50?
#                       Y Decision: X['don't'] <= 0.50?
#                         Y Decision: X['good'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.545 (11 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.444 (9 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.333 (9 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.100 (10 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.071 (14 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#                 N Decision: X['a_great'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 0.000 (11 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.100 (10 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (13 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.800 (10 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.900 (10 total training examples)
#         N Decision: X['enjoy'] <= 0.50?
#           Y Leaf: p(y=1 | this leaf) = 0.625 (16 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.889 (9 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Decision: X['book'] <= 0.50?
#         Y Decision: X['sound'] <= 0.50?
#           Y Decision: X['find'] <= 0.50?
#             Y Decision: X['i_have'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 0.000 (34 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.111 (9 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.300 (10 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.333 (12 total training examples)
#         N Leaf: p(y=1 | this leaf) = 0.500 (14 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.833 (12 total training examples)

# %% [markdown]
# # Random forests!

# %% [markdown]
# ## 1C: Train a random forest with default settings

# %%
simple_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    criterion='entropy',
    max_features='sqrt',
    max_depth=3,
    min_samples_leaf=1,
    min_samples_split=2,
    random_state=101)

# %% [markdown]
# ### Fit the forest
#
# **TODO Train on the training set** in the next coding cell

# %%
simple_forest.fit(x_tr_NF, y_tr_N)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3, random_state=101)

# %% [markdown]
# ## 1D: Best Random Forest via grid search
#
# Follow the instructions and using what you learn above to finish this step.
#
# This block might take 2-10 minutes. (Takes about 2 min on staff Macbook laptops from before 2020.)
#
# If yours runs significantly longer, try this out on Google Colab instead.

# %%
base_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    criterion='entropy',
    max_depth=16,
    min_samples_split=2,
    min_samples_leaf=1)

# %%
forest_hyperparameter_grid_by_name = dict(
    max_features=[3, 10, 33, 100, 333],
    max_depth=[16, 32],
    min_samples_leaf=[1],
    n_estimators=[100],
    random_state=[101],
    )

# %%
# Make sure you point it to our predefined split
forest_searcher = sklearn.model_selection.GridSearchCV(
    estimator=base_forest,
    param_grid=forest_hyperparameter_grid_by_name,
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False,
)

# %% [markdown]
# ### Do the search!

# %%
start_time_sec = time.time()
forest_searcher.fit(xall_LF, yall_L)
elapsed_time_sec = time.time() - start_time_sec

# %% [markdown]
# ### Build dataframe of results

# %%
# Convert grid search results to a DataFrame
forest_results_df = pd.DataFrame(forest_searcher.cv_results_)
# Sort by best validation score
forest_results_df = forest_results_df.sort_values(
    by='mean_test_score', ascending=False
)
# Show top few rows
forest_results_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6         2.4921           0.0           0.1480             0.0
# 8        15.8675           0.0           0.0691             0.0
# 1         1.6869           0.0           0.0786             0.0
# 7         6.6287           0.0           0.0820             0.0
# 3         9.1792           0.0           0.0568             0.0
#
#    param_max_depth  param_max_features  param_min_samples_leaf  \
# 6               32                  10                       1
# 8               32                 100                       1
# 1               16                  10                       1
# 7               32                  33                       1
# 3               16                 100                       1
#
#    param_n_estimators  param_random_state  \
# 6                 100                 101
# 8                 100                 101
# 1                 100                 101
# 7                 100                 101
# 3                 100                 101
#
#                                               params  split0_test_score  \
# 6  {'max_depth': 32, 'max_features': 10, 'min_sam...             0.8620
# 8  {'max_depth': 32, 'max_features': 100, 'min_sa...             0.8469
# 1  {'max_depth': 16, 'max_features': 10, 'min_sam...             0.8458
# 7  {'max_depth': 32, 'max_features': 33, 'min_sam...             0.8422
# 3  {'max_depth': 16, 'max_features': 100, 'min_sa...             0.8409
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 6           0.8620             0.0                1              0.9724
# 8           0.8469             0.0                2              0.9694
# 1           0.8458             0.0                3              0.9272
# 7           0.8422             0.0                4              0.9635
# 3           0.8409             0.0                5              0.9130
#
#    mean_train_score  std_train_score
# 6            0.9724              0.0
# 8            0.9694              0.0
# 1            0.9272              0.0
# 7            0.9635              0.0
# 3            0.9130              0.0

# %% [markdown]
# ### Display search results

# %%
print("Best parameters:", forest_searcher.best_params_)
print("Best balanced accuracy: %.3f" % forest_searcher.best_score_)
# Out:
# Best parameters: {'max_depth': 32, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100, 'random_state': 101}
# Best balanced accuracy: 0.862

# %% [markdown]
# ### Build the best random forest using the best hyperparameters found
#
# This is necessary so you have the specific best performing forest in your workspace.
#
# Train *only* on training set (do not merge train and valid)

# %%
# Build & train best forest (train set only)
best_forest = base_forest.set_params(**forest_searcher.best_params_)
best_forest.fit(x_tr_NF, y_tr_N)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=32, max_features=10,
#                        random_state=101)

# %% [markdown]
# ## Table 2: Comparison of methods on the bag-of-words to sentiment classification task.
#
# Remember, in your workspace, you should have the following models defined
#
# * `simple_tree`, from 1A
# * `best_tree`, from 1B
# * `simple_forest`, from 1C
# * `best_forest`, from 1D
#
#
# Please report **balanced accuracy** on the train, valid, and test sets, to 3 digits of precision
#
# **Sample Output** (Feel free to print all values and organize them by hand)
#
# |**method**|**max depth**|**num trees**|**train BAcc**|**valid BAcc**|**test BAcc**|
# |:-|:-:|:-:|:-:|:-:|:-:|
# |simple Tree	| 1 | 1 | 0.123	|0.456	|0.890|
# |best Tree	|1 | 1 | 0.123	|0.456	|0.890|
# |simple RandomForest	|1 | 1 | 0.123	|0.456	|0.890|
# |best RandomForest	|1 | 1 | 0.123	|0.456	|0.890|

# %%
# Compute balanced accuracy for each dataset and model

results = []

# 1. Simple Decision Tree
yhat_tr = simple_tree.predict(x_tr_NF)
yhat_valid = simple_tree.predict(x_va_TF)
yhat_test = simple_tree.predict(x_te_TF)
results.append({
    'Model': 'Simple Decision Tree',
    '# Trees': 1,
    'max_depth': simple_tree.max_depth,
    'Train BA': sklearn.metrics.balanced_accuracy_score(y_tr_N, yhat_tr),
    'Valid BA': sklearn.metrics.balanced_accuracy_score(y_va_T, yhat_valid),
    'Test BA': sklearn.metrics.balanced_accuracy_score(y_te_T, yhat_test)
})

# 2. Best Decision Tree
yhat_tr = best_tree.predict(x_tr_NF)
yhat_valid = best_tree.predict(x_va_TF)
yhat_test = best_tree.predict(x_te_TF)
results.append({
    'Model': 'Best Decision Tree',
    '# Trees': 1,
    'max_depth': best_tree.max_depth,
    'Train BA': sklearn.metrics.balanced_accuracy_score(y_tr_N, yhat_tr),
    'Valid BA': sklearn.metrics.balanced_accuracy_score(y_va_T, yhat_valid),
    'Test BA': sklearn.metrics.balanced_accuracy_score(y_te_T, yhat_test)
})

# 3. Simple Random Forest
yhat_tr = simple_forest.predict(x_tr_NF)
yhat_valid = simple_forest.predict(x_va_TF)
yhat_test = simple_forest.predict(x_te_TF)
results.append({
    'Model': 'Simple Random Forest',
    '# Trees': simple_forest.n_estimators,
    'max_depth': simple_forest.max_depth,
    'Train BA': sklearn.metrics.balanced_accuracy_score(y_tr_N, yhat_tr),
    'Valid BA': sklearn.metrics.balanced_accuracy_score(y_va_T, yhat_valid),
    'Test BA': sklearn.metrics.balanced_accuracy_score(y_te_T, yhat_test)
})

# 4. Best Random Forest
yhat_tr = best_forest.predict(x_tr_NF)
yhat_valid = best_forest.predict(x_va_TF)
yhat_test = best_forest.predict(x_te_TF)
results.append({
    'Model': 'Best Random Forest',
    '# Trees': best_forest.n_estimators,
    'max_depth': best_forest.max_depth,
    'Train BA': sklearn.metrics.balanced_accuracy_score(y_tr_N, yhat_tr),
    'Valid BA': sklearn.metrics.balanced_accuracy_score(y_va_T, yhat_valid),
    'Test BA': sklearn.metrics.balanced_accuracy_score(y_te_T, yhat_test)
})

# Make DataFrame
table2_df = pd.DataFrame(results)

# Round for clarity
table2_df = table2_df.round(3)

# Print nicely
print("Table 2. Balanced Accuracy of all Models (Train, Validation, Test)")
display(table2_df)
# Out:
# Table 2. Balanced Accuracy of all Models (Train, Validation, Test)
#                   Model  # Trees  max_depth  Train BA  Valid BA  Test BA
# 0  Simple Decision Tree        1          3     0.646     0.643    0.647
# 1    Best Decision Tree        1        128     0.844     0.724    0.735
# 2  Simple Random Forest      100          3     0.815     0.795    0.774
# 3    Best Random Forest      100         32     0.972     0.862    0.806
